# %%
import pandas as pd


path = '../../../data/heart_disease/output/filled_missing.csv'
df = pd.read_csv(path, index_col=0)[['age', 'trestbps', 'chol', 'fbs', 'thalch', 'exang', 'disease']]
df
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 import pandas as pd
#       4 path = '../../../data/heart_disease/output/filled_missing.csv'
#       5 df = pd.read_csv(path, index_col=0)[['age', 'trestbps', 'chol', 'fbs', 'thalch', 'exang', 'disease']]
#
# Cell In[16], line 1
# ----> 1 import pandas as pd
#       4 path = '../../../data/heart_disease/output/filled_missing.csv'
#       5 df = pd.read_csv(path, index_col=0)[['age', 'trestbps', 'chol', 'fbs', 'thalch', 'exang', 'disease']]
#
# File _pydevd_bundle\\pydevd_cython.pyx:1697, in _pydevd_bundle.pydevd_cython.SafeCallWrapper.__call__()
#
# File _pydevd_bundle\\pydevd_cython.pyx:635, in _pydevd_bundle.pydevd_cython.PyDBFrame.trace_dispatch()
#
# File _pydevd_bundle\\pydevd_cython.pyx:1112, in _pydevd_bundle.pydevd_cython.PyDBFrame.trace_dispatch()
#
# File _pydevd_bundle\\pydevd_cython.pyx:1090, in _pydevd_bundle.pydevd_cython.PyDBFrame.trace_dispatch()
#
# File _pydevd_bundle\\pydevd_cython.pyx:495, in _pydevd_bundle.pydevd_cython.PyDBFrame.do_wait_suspend()
#
# File ~/.local/lib/python3.11/site-packages/debugpy/_vendored/pydevd/pydevd.py:2197, in PyDB.do_wait_suspend(self, thread, frame, event, arg, exception_type)
#    2194             from_this_thread.append(frame_custom_thread_id)
#    2196     with self._threads_suspended_single_notification.notify_thread_suspended(thread_id, thread, stop_reason):
# -> 2197         keep_suspended = self._do_wait_suspend(thread, frame, event, arg, trace_suspend_type, from_this_thread, frames_tracker)
#    2199 frames_list = None
#    2201 if keep_suspended:
#    2202     # This means that we should pause again after a set next statement.
#
# File ~/.local/lib/python3.11/site-packages/debugpy/_vendored/pydevd/pydevd.py:2266, in PyDB._do_wait_suspend(self, thread, frame, event, arg, trace_suspend_type, from_this_thread, frames_tracker)
#    2263                 queue.put(internal_cmd)
#    2264                 wait_timeout = TIMEOUT_FAST
# -> 2266         notify_event.wait(wait_timeout)
#    2267         notify_event.clear()
#    2269 finally:
#
# File /usr/local/lib/python3.11/threading.py:622, in Event.wait(self, timeout)
#     620 signaled = self._flag
#     621 if not signaled:
# --> 622     signaled = self._cond.wait(timeout)
#     623 return signaled
#
# File /usr/local/lib/python3.11/threading.py:324, in Condition.wait(self, timeout)
#     322 else:
#     323     if timeout > 0:
# --> 324         gotit = waiter.acquire(True, timeout)
#     325     else:
#     326         gotit = waiter.acquire(False)
#
# KeyboardInterrupt:

# %%
target = 'disease'

y = df[target]
X = df.drop(columns=target)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
from sklearn.tree import DecisionTreeClassifier
model=DecisionTreeClassifier()

# %%
model.get_params()
# Out:
# {'ccp_alpha': 0.0,
#  'class_weight': None,
#  'criterion': 'gini',
#  'max_depth': None,
#  'max_features': None,
#  'max_leaf_nodes': None,
#  'min_impurity_decrease': 0.0,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'monotonic_cst': None,
#  'random_state': None,
#  'splitter': 'best'}

# %%
param_grid = {
    'max_depth': [3, 5, 7, 9],
    'min_samples_leaf': [50,100,150,200],
    'criterion': ['gini', 'entropy']
}

# %%
from sklearn.model_selection import GridSearchCV
model_grid = GridSearchCV(model, param_grid, cv=3, verbose=1)

# %%
model_grid.fit(X_train, y_train)
# Out:
# Fitting 3 folds for each of 32 candidates, totalling 96 fits
# GridSearchCV(cv=3, estimator=DecisionTreeClassifier(),
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [3, 5, 7, 9],
#                          'min_samples_leaf': [50, 100, 150, 200]},
#              verbose=1)

# %%
model_grid.best_estimator_
# Out:
# DecisionTreeClassifier(max_depth=3, min_samples_leaf=100)

# %%
pip install Jinja2
# Out:
# 1549.05s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: Jinja2 in /home/vscode/.local/lib/python3.11/site-packages (3.1.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/vscode/.local/lib/python3.11/site-packages (from Jinja2) (2.1.5)
#
# [notice] A new release of pip is available: 23.1.2 -> 24.2
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
df_results = pd.DataFrame(model_grid.cv_results_)

(df_results
 .loc[:, ['params', 'mean_test_score', 'rank_test_score']]
 .sort_values(by='rank_test_score')
 .style
 )
# Out:
# <style type="text/css">
# </style>
# <table id="T_6b923">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6b923_level0_col0" class="col_heading level0 col0" >params</th>
#       <th id="T_6b923_level0_col1" class="col_heading level0 col1" >mean_test_score</th>
#       <th id="T_6b923_level0_col2" class="col_heading level0 col2" >rank_test_score</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6b923_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_6b923_row0_col0" class="data row0 col0" >{'criterion': 'gini', 'max_depth': 3, 'min_samples_leaf': 100}</td>
#       <td id="T_6b923_row0_col1" class="data row0 col1" >0.549692</td>
#       <td id="T_6b923_row0_col2" class="data row0 col2" >1</td>
#     </tr>
#     <tr>
#       <th id="T_6b923_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_6b923_row1_col0" class="data row1 col0" >{'criterion': 'gini', 'max_depth': 3, 'min_samples_leaf': 150}</td>
#       <td id="T_6b923_row1_col1" class="data row1 col1" >0.549692</td>
#       <td id="T_6b923_row1_col2" class="data row1 col2" >1</td>
#     </tr>
#     <tr>
#       <th id="T_6b923_level0_row2" class="row_heading level0 row2" >6</th>
#       <td id="T_6b923_row2_col0" class="data row2 col0" >{'criterion': 'gini', 'max_depth': 5, 'min_samples_leaf': 150}</td>
#       <td id="T_6b923_row2_col1" class="data row2 col1" >0.549692</td>
#       <td id="T_6b923_row2_col2" class="data row2 col2" >1</td>
#     </tr>
#     <tr>
#       <th id="T_6b923_level0_row3" class="row_heading level0 row3" >5</th>
#       <td id="T_6b923_row3_col0" class="data row3 col0" >{'criterion': 'gini', 'max_depth': 5, 'min_samples_leaf': 100}</td>
#       <td id="T_6b923_row3_col1" class="data row3 col1" >0.549692</td>
#       <td id="T_6b923_row3_col2" class="data row3 col2" >1</td>
#     </tr>
#     <tr>
#       <th id="T_6b923_level0_row4" class="row_heading level0 row4" >13</th>
#       <td id="T_6b923_row4_col0" class="data row4 col0" >{'criterion': 'gini', 'max_depth': 9, 'min_samples_leaf': 100}</td>
#       <td id="T_6b923_row4_col1" class="data row4 col1" >0.549692</td>
#       <td id="T_6b923_row4_col2" class="data row4 col2" >1</td>
#     </tr>
#     <tr>
#       <th id="T_6b923_level0_row5" class="row_heading level0 row5" >14</th>
#       <td id="T_6b923_row5_col0" class="data row5 col0" >{'criterion': 'gini', 'max_depth': 9, 'min_samples_leaf': 150}</td>
#       <td id="T_6b923_row5_col1" class="data row5 col1" >0.549692</td>
#       <td id="T_6b923_row5_col2" class="data row5 col2" >1</td>
#     </tr>
#     <tr>
#       <th id="T_6b923_level0_row6" class="row_heading level0 row6" >10</th>
#       <td id="T_6b923_row6_col0" class="data row6 col0" >{'criterion': 'gini', 'max_depth': 7, 'min_samples_leaf': 150}</td>
#       <td id="T_6b923_row6_col1" class="data row6 col1" >0.549692</td>
#       <td id="T_6b923_row6_col2" class="data row6 col2" >1</td>
#     </tr>
#     <tr>
#       <th id="T_6b923_level0_row7" class="row_heading level0 row7" >9</th>
#       <td id="T_6b923_row7_col0" class="data row7 col0" >{'criterion': 'gini', 'max_depth': 7, 'min_samples_leaf': 100}</td>
#       <td id="T_6b923_row7_col1" class="data row7 col1" >0.549692</td>
#       <td id="T_6b923_row7_col2" class="data row7 col2" >1</td>
#     </tr>
#     <tr>
#       <th id="T_6b923_level0_row8" class="row_heading level0 row8" >25</th>
#       <td id="T_6b923_row8_col0" class="data row8 col0" >{'criterion': 'entropy', 'max_depth': 7, 'min_samples_leaf': 100}</td>
#       <td id="T_6b923_row8_col1" class="data row8 col1" >0.549692</td>
#       <td id="T_6b923_row8_col2" class="data row8 col2" >1</td>
#     </tr>
#     <tr>
#       <th id="T_6b923_level0_row9" class="row_heading level0 row9" >26</th>
#       <td id="T_6b923_row9_col0" class="data row9 col0" >{'criterion': 'entropy', 'max_depth': 7, 'min_samples_leaf': 150}</td>
#       <td id="T_6b923_row9_col1" class="data row9 col1" >0.549692</td>
#       <td id="T_6b923_row9_col2" class="data row9 col2" >1</td>
#     </tr>
#     <tr>
#       <th id="T_6b923_level0_row10" class="row_heading level0 row10" >30</th>
#       <td id="T_6b923_row10_col0" class="data row10 col0" >{'criterion': 'entropy', 'max_depth': 9, 'min_samples_leaf': 150}</td>
#       <td id="T_6b923_row10_col1" class="data row10 col1" >0.549692</td>
#       <td id="T_6b923_row10_col2" class="data row10 col2" >1</td>
#     </tr>
#     <tr>
#       <th id="T_6b923_level0_row11" class="row_heading level0 row11" >29</th>
#       <td id="T_6b923_row11_col0" class="data row11 col0" >{'criterion': 'entropy', 'max_depth': 9, 'min_samples_leaf': 100}</td>
#       <td id="T_6b923_row11_col1" class="data row11 col1" >0.549692</td>
#       <td id="T_6b923_row11_col2" class="data row11 col2" >1</td>
#     </tr>
#     <tr>
#       <th id="T_6b923_level0_row12" class="row_heading level0 row12" >21</th>
#       <td id="T_6b923_row12_col0" class="data row12 col0" >{'criterion': 'entropy', 'max_depth': 5, 'min_samples_leaf': 100}</td>
#       <td id="T_6b923_row12_col1" class="data row12 col1" >0.549692</td>
#       <td id="T_6b923_row12_col2" class="data row12 col2" >1</td>
#     </tr>
#     <tr>
#       <th id="T_6b923_level0_row13" class="row_heading level0 row13" >22</th>
#       <td id="T_6b923_row13_col0" class="data row13 col0" >{'criterion': 'entropy', 'max_depth': 5, 'min_samples_leaf': 150}</td>
#       <td id="T_6b923_row13_col1" class="data row13 col1" >0.549692</td>
#       <td id="T_6b923_row13_col2" class="data row13 col2" >1</td>
#     </tr>
#     <tr>
#       <th id="T_6b923_level0_row14" class="row_heading level0 row14" >18</th>
#       <td id="T_6b923_row14_col0" class="data row14 col0" >{'criterion': 'entropy', 'max_depth': 3, 'min_samples_leaf': 150}</td>
#       <td id="T_6b923_row14_col1" class="data row14 col1" >0.549692</td>
#       <td id="T_6b923_row14_col2" class="data row14 col2" >1</td>
#     </tr>
#     <tr>
#       <th id="T_6b923_level0_row15" class="row_heading level0 row15" >17</th>
#       <td id="T_6b923_row15_col0" class="data row15 col0" >{'criterion': 'entropy', 'max_depth': 3, 'min_samples_leaf': 100}</td>
#       <td id="T_6b923_row15_col1" class="data row15 col1" >0.549692</td>
#       <td id="T_6b923_row15_col2" class="data row15 col2" >1</td>
#     </tr>
#     <tr>
#       <th id="T_6b923_level0_row16" class="row_heading level0 row16" >28</th>
#       <td id="T_6b923_row16_col0" class="data row16 col0" >{'criterion': 'entropy', 'max_depth': 9, 'min_samples_leaf': 50}</td>
#       <td id="T_6b923_row16_col1" class="data row16 col1" >0.546606</td>
#       <td id="T_6b923_row16_col2" class="data row16 col2" >17</td>
#     </tr>
#     <tr>
#       <th id="T_6b923_level0_row17" class="row_heading level0 row17" >24</th>
#       <td id="T_6b923_row17_col0" class="data row17 col0" >{'criterion': 'entropy', 'max_depth': 7, 'min_samples_leaf': 50}</td>
#       <td id="T_6b923_row17_col1" class="data row17 col1" >0.546606</td>
#       <td id="T_6b923_row17_col2" class="data row17 col2" >17</td>
#     </tr>
#     <tr>
#       <th id="T_6b923_level0_row18" class="row_heading level0 row18" >16</th>
#       <td id="T_6b923_row18_col0" class="data row18 col0" >{'criterion': 'entropy', 'max_depth': 3, 'min_samples_leaf': 50}</td>
#       <td id="T_6b923_row18_col1" class="data row18 col1" >0.546606</td>
#       <td id="T_6b923_row18_col2" class="data row18 col2" >17</td>
#     </tr>
#     <tr>
#       <th id="T_6b923_level0_row19" class="row_heading level0 row19" >20</th>
#       <td id="T_6b923_row19_col0" class="data row19 col0" >{'criterion': 'entropy', 'max_depth': 5, 'min_samples_leaf': 50}</td>
#       <td id="T_6b923_row19_col1" class="data row19 col1" >0.546606</td>
#       <td id="T_6b923_row19_col2" class="data row19 col2" >17</td>
#     </tr>
#     <tr>
#       <th id="T_6b923_level0_row20" class="row_heading level0 row20" >4</th>
#       <td id="T_6b923_row20_col0" class="data row20 col0" >{'criterion': 'gini', 'max_depth': 5, 'min_samples_leaf': 50}</td>
#       <td id="T_6b923_row20_col1" class="data row20 col1" >0.546606</td>
#       <td id="T_6b923_row20_col2" class="data row20 col2" >17</td>
#     </tr>
#     <tr>
#       <th id
